# %%
import PIL
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
#horizondal convolution

img=cv2.imread("images.jpeg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
img_copy=img[:]

# %%
# horizondal convolusion matrix
img_gray=cv2.cvtColor(img_copy,cv2.COLOR_RGB2GRAY)
conv_matrix=np.array([[1,1],
                      [-1,-1]])

# %%
#horz_img=img_gray*conv_matrix
img_gray.shape
for i,j in zip[]
# Out:
# (273, 184)
